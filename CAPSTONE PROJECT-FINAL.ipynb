# %% [markdown]
# <h1>A program For Photographers Event<h1>
#     <h2>Introduction</h2>
# <p>XYZ is a company based in Toronto for organizing events, currently it works on a project to organize an event for 6 days for a group of photographers from all over the world.The company has to put a good program, including a hotel of residence, a hall for meetings, places of landscape to visit, stores for shopping, restaurants and cafes. So the company’s purpose is to make a list of places of landscape in Toronto, including the nearest restaurants, cafes, and shopping stores for each place</p>

# %% [markdown]
# <h2>Table of contents</h2>
# 1- Import Libraries<br>
# 2- Define Foursquare Credentials <br>
# 3- Search for Hotels <br>
# <h2>Import Libraries</h2>

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.5.15-1                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.6.16-py36_1              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_1             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
ClIENT_ID = '4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P' # your Foursquare ID
ClIENT_SECRET = 'SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: 4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P
# Foursquare_Secret:SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %% [markdown]
# <h2>SEARCH FOR HOTELS</h2>

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P&client_secret=SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 3  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
# 4  5545d07e498e2facac03f666  123 Queen Street West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                390
# 1           Canada  Queen & St. Patrick                400
# 2           Canada          Dundas St W                124
# 3           Canada      at somewhere St                500
# 4           Canada        at Bay Street                376
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...     43.651144
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
# 4  [{'label': 'display', 'lat': 43.65119976208405...     43.651200
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384329                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.385942                   NaN             M5G 1R3             ON
# 3    -79.387894                   NaN             M2M 2M2             ON
# 4    -79.384520    Financial District                 NaN             ON
#
#                                              name    referralId venuePage.id
# 0                   Sheraton Centre Toronto Hotel  v-1570568578          NaN
# 1                  The Rex Hotel Jazz & Blues Bar  v-1570568578     62225795
# 2     DoubleTree by Hilton Hotel Toronto Downtown  v-1570568578          NaN
# 3                                  VFM Test Hotel  v-1570568578          NaN
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom  v-1570568578          NaN

# %% [markdown]
# <h2>CLEAN HOTEL DATAFRAME</h2>

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2     DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 3                                  VFM Test Hotel      Hotel
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       390
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 3         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
# 4  123 Queen Street West  CA  Toronto  Canada        at Bay Street       376
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...  43.651144 -79.384329
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
# 4  [{'label': 'display', 'lat': 43.65119976208405...  43.651200 -79.384520
#
#          neighborhood postalCode state                        id
# 0                 NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1                 NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2                 NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 3                 NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90
# 4  Financial District        NaN    ON  5545d07e498e2facac03f666

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress','labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                   VFM Test Hotel                   Hotel
# 4   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 5                                  Stathcona Hotel                   Hotel
# 6    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 7                                   Hilton Toronto                   Hotel
# 8                Sheraton Centre Hotel Club Lounge                  Lounge
# 9                                        650 Hotel                   Hotel
# 10                               Be SixFifty Hotel                   Hotel
# 11                              Shangri-La Toronto                   Hotel
# 12    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 13                           89 Chestnut Residence  College Residence Hall
# 14                   Op mijn hotelkamer In Toronto                   Hotel
# 15          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                  Fitness Centre                     Gym
# 17                                  Fitness Centre                     Gym
# 18                                   Kumar For Men             Men's Store
# 19                                            Pool                    Pool
# 20                                  Grand Ballroom             Event Space
# 21                                   Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 4   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 5                     NaN  43.654947 -79.386359        NaN       ON
# 6   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 7       145 Richmond St W  43.649946 -79.385479    M5H 2L2       ON
# 8                     NaN  43.651063 -79.384527    M5H 2M9       ON
# 9          650 Bay Street  43.657046 -79.384411        NaN       ON
# 10         650 Bay Street  43.657120 -79.384560        NaN       ON
# 11    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 14                    NaN  43.654235 -79.386208        NaN       ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 17        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 18        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 19       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                 VFM Test Hotel                   Hotel
# 7                                 Hilton Toronto                   Hotel
# 11                            Shangri-La Toronto                   Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 13                         89 Chestnut Residence  College Residence Hall
# 15        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                Fitness Centre                     Gym
# 17                                Fitness Centre                     Gym
# 18                                 Kumar For Men             Men's Store
# 20                                Grand Ballroom             Event Space
# 21                                 Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 17        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 18        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 21        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 7                                 Hilton Toronto        Hotel
# 11                            Shangri-La Toronto        Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 20                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 7                                 Hilton Toronto        Hotel
# 11                            Shangri-La Toronto        Hotel
# 12  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 20                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 12         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 20        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 20                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651144 -79.384329    M5H 2M9    ON
# 20  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# <h2>Search For Parks</h2>

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P&client_secret=SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
#
#                          id    location.address location.cc location.city  \
# 0  4b170e47f964a5208cc123e3  691 University Ave          CA       Toronto
# 1  4b54deadf964a520a3d027e3                 NaN          CA       Toronto
# 2  4ad4c05ef964a520bdf620e3  1053 Dundas St. W.          CA       Toronto
# 3  4bb3c91a2397b7134d9f38b3         Spadina Ave          CA       Toronto
# 4  4ad80fcef964a520a61021e3       280 Simcoe St          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada        at College St                716
# 1           Canada                  NaN                423
# 2           Canada    at Gore Vale Ave.               2271
# 3           Canada   at Wellington St W               1223
# 4           Canada   Dundas Street West                282
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [280 Simcoe St (Dundas Street West), Toronto O...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.64707192840234...     43.647072
# 3  [{'label': 'display', 'lat': 43.64422227794523...     43.644222
# 4  [{'label': 'display', 'lat': 43.65544241747622...     43.655442
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.413756             M5H 2N2             ON
# 3    -79.394230                 NaN             ON
# 4    -79.390056             M5T 2Y5             ON
#
#                           name    referralId venuePage.id
# 0  Queen's Park Subway Station  v-1570568669          NaN
# 1                  Grange Park  v-1570568669          NaN
# 2       Trinity Bellwoods Park  v-1570568669          NaN
# 3         Clarence Square Park  v-1570568669          NaN
# 4                One Park Lane  v-1570568669          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                           name                                categories  \
# 0  Queen's Park Subway Station                             Metro Station
# 1                  Grange Park                                      Park
# 2       Trinity Bellwoods Park                                      Park
# 3         Clarence Square Park                                      Park
# 4                One Park Lane  Residential Building (Apartment / Condo)
#
#               address  cc     city country         crossStreet  distance  \
# 0  691 University Ave  CA  Toronto  Canada       at College St       716
# 1                 NaN  CA  Toronto  Canada                 NaN       423
# 2  1053 Dundas St. W.  CA  Toronto  Canada   at Gore Vale Ave.      2271
# 3         Spadina Ave  CA  Toronto  Canada  at Wellington St W      1223
# 4       280 Simcoe St  CA  Toronto  Canada  Dundas Street West       282
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [280 Simcoe St (Dundas Street West), Toronto O...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.64707192840234...  43.647072 -79.413756
# 3  [{'label': 'display', 'lat': 43.64422227794523...  43.644222 -79.394230
# 4  [{'label': 'display', 'lat': 43.65544241747622...  43.655442 -79.390056
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5H 2N2    ON  4ad4c05ef964a520bdf620e3
# 3        NaN    ON  4bb3c91a2397b7134d9f38b3
# 4    M5T 2Y5    ON  4ad80fcef964a520a61021e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 1                               Grange Park
# 2                    Trinity Bellwoods Park
# 3                      Clarence Square Park
# 4                             One Park Lane
# 5                               Berczy Park
# 6                              Queen's Park
# 7             Crunch Fitness - College Park
# 8                      Bellevue Square Park
# 9          Residences at College Park North
# 10        St. Andrews Playground / Dog Park
# 11                                 HTO Park
# 12       TTC Streetcar #403 - Victoria park
# 13  GoodLife Fitness Toronto Bloor and Park
# 14                      Riverdale Park East
# 15                      Riverdale Park West
# 16                             Stanley Park
# 17                      RBC WaterPark Place
# 18                             College Park
# 19                                High Park
# 20                   Physiomed College Park
# 21                       Canoe Landing Park
# 22         Toothworks - College Park Dental
# 23                        Barbara Hall Park
# 24                   Parliament Square Park
# 25                          Coronation Park
# 26                  Cawthra Square Dog Park
# 27                  St Lawrence on the Park
# 28                        Osgoode Hall Park
# 29                      Dufferin Grove Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park            1053 Dundas St. W.
# 3                                       Park                   Spadina Ave
# 4   Residential Building (Apartment / Condo)                 280 Simcoe St
# 5                                       Park        35 Wellington St. East
# 6                                       Park               University Ave.
# 7                       Gym / Fitness Center              382 Yonge Street
# 8                                       Park  btwn Bellevue & Augusta Ave.
# 9   Residential Building (Apartment / Condo)                   763 Bay St.
# 10                                      Park      450 Adelaide Street West
# 11                                      Park                  Queen's Quay
# 12                        Light Rail Station                           NaN
# 13                                       Gym                     8 Park Rd
# 14                                      Park             550 Broadview Ave
# 15                                      Park               500 Gerrard St.
# 16                                      Park              King Street West
# 17                                    Office                88 Queens Quay
# 18                             Shopping Mall                  444 Yonge St
# 19                                      Park              1873 Bloor St. W
# 20                            Medical Center                  382 Yonge St
# 21                                      Park             50 Fort York Blvd
# 22                          Dentist's Office        444 Yonge St, Unit M16
# 23                                      Park             519 Church Street
# 24                                      Park          44 Parliament Street
# 25                                      Park        711 Lake Shore Blvd. W
# 26                                   Dog Run                519 Church St.
# 27                                  Building               65 Scadding Ave
# 28                                      Park                130 Queen St W
# 29                                      Park               875 Dufferin St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.647072 -79.413756    M5H 2N2    ON
# 3   43.644222 -79.394230        NaN    ON
# 4   43.655442 -79.390056    M5T 2Y5    ON
# 5   43.648048 -79.375172        NaN    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 7   43.659263 -79.382632    M5G 1S8    ON
# 8   43.653610 -79.402199    M5T 2N4    ON
# 9   43.659822 -79.385159    M5G 2R3    ON
# 10  43.647388 -79.398752        NaN    ON
# 11  43.637949 -79.387820        NaN    ON
# 12  43.650735 -79.386921        NaN    ON
# 13  43.671302 -79.384691    M4W 3G8    ON
# 14  43.669951 -79.355493    M4K 2P1    ON
# 15  43.666048 -79.360941    M5A 2H3    ON
# 16  43.642395 -79.409330        NaN    ON
# 17  43.641075 -79.379154        NaN    ON
# 18  43.661237 -79.383603    M5B 2H4    ON
# 19  43.646479 -79.463425    M6R 2Z3    ON
# 20  43.659240 -79.382860    M5B 1S8    ON
# 21  43.638762 -79.397067    M5V 3Z1    ON
# 22  43.660009 -79.383905        NaN    ON
# 23  43.666728 -79.381084        NaN    ON
# 24  43.650264 -79.362195        NaN    ON
# 25  43.634553 -79.405403    M5V 3T7    ON
# 26  43.666583 -79.380040        NaN    ON
# 27  43.648963 -79.364868        NaN    ON
# 28  43.651105 -79.386269    M5H 2N5    ON
# 29  43.656052 -79.431915        M6H    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                        name  \
# 0               Queen's Park Subway Station
# 2                    Trinity Bellwoods Park
# 4                             One Park Lane
# 6                              Queen's Park
# 7             Crunch Fitness - College Park
# 8                      Bellevue Square Park
# 9          Residences at College Park North
# 13  GoodLife Fitness Toronto Bloor and Park
# 14                      Riverdale Park East
# 15                      Riverdale Park West
# 18                             College Park
# 19                                High Park
# 20                   Physiomed College Park
# 21                       Canoe Landing Park
# 25                          Coronation Park
# 28                        Osgoode Hall Park
# 29                      Dufferin Grove Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                                       Park            1053 Dundas St. W.
# 4   Residential Building (Apartment / Condo)                 280 Simcoe St
# 6                                       Park               University Ave.
# 7                       Gym / Fitness Center              382 Yonge Street
# 8                                       Park  btwn Bellevue & Augusta Ave.
# 9   Residential Building (Apartment / Condo)                   763 Bay St.
# 13                                       Gym                     8 Park Rd
# 14                                      Park             550 Broadview Ave
# 15                                      Park               500 Gerrard St.
# 18                             Shopping Mall                  444 Yonge St
# 19                                      Park              1873 Bloor St. W
# 20                            Medical Center                  382 Yonge St
# 21                                      Park             50 Fort York Blvd
# 25                                      Park        711 Lake Shore Blvd. W
# 28                                      Park                130 Queen St W
# 29                                      Park               875 Dufferin St
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.647072 -79.413756    M5H 2N2    ON
# 4   43.655442 -79.390056    M5T 2Y5    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 7   43.659263 -79.382632    M5G 1S8    ON
# 8   43.653610 -79.402199    M5T 2N4    ON
# 9   43.659822 -79.385159    M5G 2R3    ON
# 13  43.671302 -79.384691    M4W 3G8    ON
# 14  43.669951 -79.355493    M4K 2P1    ON
# 15  43.666048 -79.360941    M5A 2H3    ON
# 18  43.661237 -79.383603    M5B 2H4    ON
# 19  43.646479 -79.463425    M6R 2Z3    ON
# 20  43.659240 -79.382860    M5B 1S8    ON
# 21  43.638762 -79.397067    M5V 3Z1    ON
# 25  43.634553 -79.405403    M5V 3T7    ON
# 28  43.651105 -79.386269    M5H 2N5    ON
# 29  43.656052 -79.431915        M6H    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 6             Queen's Park       Park               University Ave.
# 8     Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 14     Riverdale Park East       Park             550 Broadview Ave
# 15     Riverdale Park West       Park               500 Gerrard St.
# 19               High Park       Park              1873 Bloor St. W
# 21      Canoe Landing Park       Park             50 Fort York Blvd
# 25         Coronation Park       Park        711 Lake Shore Blvd. W
# 28       Osgoode Hall Park       Park                130 Queen St W
# 29     Dufferin Grove Park       Park               875 Dufferin St
#
#           lat        lng postalCode state
# 2   43.647072 -79.413756    M5H 2N2    ON
# 6   43.663946 -79.392180    M5R 2E8    ON
# 8   43.653610 -79.402199    M5T 2N4    ON
# 14  43.669951 -79.355493    M4K 2P1    ON
# 15  43.666048 -79.360941    M5A 2H3    ON
# 19  43.646479 -79.463425    M6R 2Z3    ON
# 21  43.638762 -79.397067    M5V 3Z1    ON
# 25  43.634553 -79.405403    M5V 3T7    ON
# 28  43.651105 -79.386269    M5H 2N5    ON
# 29  43.656052 -79.431915        M6H    ON

# %% [markdown]
# <h2>Search For Resturant</h2>

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P&client_secret=SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 2  4b223f5af964a520ba4424e3        225 Frnt St W          CA       Toronto
# 3  4ae29812f964a520288f21e3     309 Spadina Ave.          CA       Toronto
# 4  4ad4c05cf964a520dff520e3       301 Front St W          CA       Toronto
#
#   location.country            location.crossStreet  location.distance  \
# 0           Canada                             NaN                145
# 1           Canada                   at D'Arcy St.                922
# 2           Canada                             NaN               1039
# 3           Canada  btwn Dundas St. W & D'Arcy St.                896
# 4           Canada                 301 Front St. W               1271
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 4  [301 Front St W (301 Front St. W), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 2  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 3  [{'label': 'display', 'lat': 43.65386562507761...     43.653866
# 4  [{'label': 'display', 'lat': 43.64253731714456...     43.642537
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.385931                     NaN             M5G 1R3             ON
# 1    -79.398650       Kensington Market             M5T 2E9             ON
# 2    -79.385113  Entertainment District             M5V 2X3             ON
# 3    -79.398334                     NaN             M5T 2E6             ON
# 4    -79.387042                     NaN             M5V 2T6             ON
#
#                               name    referralId venuePage.id
# 0  Hemispheres Restaurant & Bistro  v-1570568761          NaN
# 1           Rol San Restaurant 龍笙棧  v-1570568761          NaN
# 2           Azure Restaurant & Bar  v-1570568761    136175835
# 3          Swatow Restaurant 汕頭小食家  v-1570568761          NaN
# 4                   360 Restaurant  v-1570568761          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
# 2           Azure Restaurant & Bar           Restaurant        225 Frnt St W
# 3          Swatow Restaurant 汕頭小食家   Chinese Restaurant     309 Spadina Ave.
# 4                   360 Restaurant             Wine Bar       301 Front St W
#
#    cc     city country                     crossStreet  distance  \
# 0  CA  Toronto  Canada                             NaN       145
# 1  CA  Toronto  Canada                   at D'Arcy St.       922
# 2  CA  Toronto  Canada                             NaN      1039
# 3  CA  Toronto  Canada  btwn Dundas St. W & D'Arcy St.       896
# 4  CA  Toronto  Canada                 301 Front St. W      1271
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 2        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
# 3  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 4  [301 Front St W (301 Front St. W), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 2  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 3  [{'label': 'display', 'lat': 43.65386562507761...  43.653866 -79.398334
# 4  [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
#
#              neighborhood postalCode state                        id
# 0                     NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1       Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 2  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 3                     NaN    M5T 2E6    ON  4ae29812f964a520288f21e3
# 4                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 4                                   360 Restaurant                 Wine Bar
# 5               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 6                   The Hot House Restaurant & Bar      American Restaurant
# 7                   Goldstone Noodle Restaurant 金石             Noodle House
# 8                            Victoria's Restaurant               Restaurant
# 9                    Green Tea Restaurant Downtown       Chinese Restaurant
# 10                         Victor Restaurant & Bar                      Bar
# 11                    Aroma Fine Indian Restaurant        Indian Restaurant
# 12         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 13                           ONE Restaurant/Lounge  New American Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15             Richtree Natural Market Restaurants               Restaurant
# 16                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 17  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 18              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 19              Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 20                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 21                     Woodlot Restaurant & Bakery  New American Restaurant
# 22               El Rancho Restaurant & Night Club                Nightclub
# 23                         The Lakeview Restaurant                    Diner
# 24                  Insomnia Restaurant and Lounge               Restaurant
# 25               Kensington Cornerstone Restaurant           Breakfast Spot
# 26                               Studio Restaurant           Breakfast Spot
# 27                            Montecito Restaurant               Restaurant
# 28                      Wah Too Seafood Restaurant       Chinese Restaurant
# 29                               SCHOOL Restaurant           Breakfast Spot
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 4                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 5                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 6                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 7                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 9   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 10                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 11                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 12                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 13                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 16                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 17            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 18                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 19               988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 20                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 21              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 22                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 23                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 24                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 25               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 28                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 29                   70 Fraser Ave.  43.637775 -79.424297    M6K 3C5    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 2                           Azure Restaurant & Bar               Restaurant
# 3                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 4                                   360 Restaurant                 Wine Bar
# 6                   The Hot House Restaurant & Bar      American Restaurant
# 7                   Goldstone Noodle Restaurant 金石             Noodle House
# 8                            Victoria's Restaurant               Restaurant
# 9                    Green Tea Restaurant Downtown       Chinese Restaurant
# 10                         Victor Restaurant & Bar                      Bar
# 11                    Aroma Fine Indian Restaurant        Indian Restaurant
# 12         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15             Richtree Natural Market Restaurants               Restaurant
# 16                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 17  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 20                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 21                     Woodlot Restaurant & Bakery  New American Restaurant
# 22               El Rancho Restaurant & Night Club                Nightclub
# 23                         The Lakeview Restaurant                    Diner
# 24                  Insomnia Restaurant and Lounge               Restaurant
# 25               Kensington Cornerstone Restaurant           Breakfast Spot
# 26                               Studio Restaurant           Breakfast Spot
# 27                            Montecito Restaurant               Restaurant
# 28                      Wah Too Seafood Restaurant       Chinese Restaurant
# 29                               SCHOOL Restaurant           Breakfast Spot
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 2                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 3                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 4                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 6                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 7                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 9   261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 10                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 11                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 12                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 16                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 17            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 20                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 21              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 22                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 23                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 24                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 25               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 28                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 29                   70 Fraser Ave.  43.637775 -79.424297    M6K 3C5    ON

# %% [markdown]
# <h2>Search For Cafeteria</h2>

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P&client_secret=SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 4  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  53bd6dfe498e6c1d3bc9333e                                        NaN
# 3  56b2c90a498e9f0e73d6bed6                             974 College St
# 4  4ec2b68a8231a83de8c45191                             100 McCaul St.
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada         Second Floor
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                260                               [Toronto ON, Canada]
# 3               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
# 3  [{'label': 'display', 'lat': 43.65341883567197...     43.653419
# 4  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.389443                 NaN             ON
# 3    -79.427678             M6H 1A5             ON
# 4    -79.391762                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1570568841
# 1              Stay Cafeteria 慢走  v-1570568841
# 2  Industrial Alliance Cafeteria  v-1570568841
# 3                      Cafeteria  v-1570568841
# 4                 OCAD Cafeteria  v-1570568841

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2  Industrial Alliance Cafeteria             Cafeteria
# 3                      Cafeteria    Mexican Restaurant
# 4                 OCAD Cafeteria     College Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                                        NaN  CA  Toronto  Canada
# 3                             974 College St  CA  Toronto  Canada
# 4                             100 McCaul St.  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2           NaN       260                               [Toronto ON, Canada]
# 3           NaN      3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
# 3  [{'label': 'display', 'lat': 43.65341883567197...  43.653419 -79.427678
# 4  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  53bd6dfe498e6c1d3bc9333e
# 3    M6H 1A5    ON  56b2c90a498e9f0e73d6bed6
# 4        NaN    ON  4ec2b68a8231a83de8c45191

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2           Industrial Alliance Cafeteria             Cafeteria
# 3                               Cafeteria    Mexican Restaurant
# 4                          OCAD Cafeteria     College Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                         Sears Cafeteria            Food Court
# 7                 Chestnut Tree Cafeteria             Cafeteria
# 8           De La Salle College Cafeteria     College Cafeteria
# 9                       Med Sci Cafeteria     College Cafeteria
# 10                  Ryerson Hub Cafeteria     College Cafeteria
# 11  George Brown College St. James Campus     Community College
# 12                     SickKids Cafeteria            Food Court
# 13              Macdonald Block Cafeteria             Cafeteria
# 14                      Robarts Cafeteria     College Cafeteria
# 15                          OMP Cafeteria             Cafeteria
# 16                      Choices Cafeteria            Food Court
# 17                       Rogers Cafeteria            Food Court
# 18    Cafeteria, Lawrence Park Collegiate           High School
# 19                       Kasala Cafeteria    African Restaurant
# 20    Cafeteria, Lawrence Park Collegiate           Event Space
# 21                             Marketeria            Restaurant
# 22                           CC Cafeteria     College Cafeteria
# 23                                The Hub     College Cafeteria
# 24                               One Hour    Chinese Restaurant
# 25               Estonian House Cafeteria                  Café
# 26                          Innis College        Student Center
# 27                             Radio Cafe            Food Court
# 28                      Glendon Cafeteria     College Cafeteria
# 29     Lawrence Park Collegiate Cafeteria           High School
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                                         NaN  43.655657 -79.389443
# 3                              974 College St  43.653419 -79.427678
# 4                              100 McCaul St.  43.652780 -79.391762
# 5                                         NaN  43.654179 -79.392555
# 6                                       Yonge  43.656038 -79.380672
# 7                          89 Chestnut Street  43.648231 -79.384045
# 8                          131 Farnham Avenue  43.683003 -79.397815
# 9                                         NaN  43.660260 -79.392977
# 10                           350 Victoria St.  43.658475 -79.377653
# 11                          200 King St. East  43.651366 -79.370158
# 12                      555 University Avenue  43.657584 -79.375652
# 13                                        NaN  43.663212 -79.388062
# 14                         130 St. George St.  43.664864 -79.399766
# 15                           1 Mount Pleasant  43.669801 -79.379790
# 16                         200 Bloor Street E  43.671411 -79.381849
# 17                                        NaN  43.669904 -79.379748
# 18                                        NaN  43.721732 -79.409600
# 19                                      Bloor  43.660759 -79.424018
# 20                                        NaN  43.723286 -79.412222
# 21                                30 Bond St.  43.653585 -79.378843
# 22                             951 Carlaw Ave  43.684631 -79.348862
# 23                           350 Victoria St.  43.658585 -79.380622
# 24                           435 Spadina Ave.  43.657399 -79.399649
# 25                       958 Broadview avenue  43.681763 -79.358246
# 26                               2 Sussex Ave  43.665556 -79.399298
# 27                          333 Bloor st east  43.671696 -79.380617
# 28                           2275 Bayview Ave  43.727383 -79.378080
# 29                                        NaN  43.722757 -79.413734
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3     M6H 1A5    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8     M4V 1H7    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN    ON
# 13        NaN   NaN
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN    ON
# 18        NaN   NaN
# 19        NaN   NaN
# 20        NaN   NaN
# 21    M5B 1W8    ON
# 22        NaN    ON
# 23    M5B 2K3    ON
# 24    M5T 2T6    ON
# 25        NaN    ON
# 26    M5S 1J5    ON
# 27        NaN    ON
# 28        NaN    ON
# 29        NaN    ON

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                              name          categories             address  \
# 1               Stay Cafeteria 慢走    Asian Restaurant     388 Spadina Ave
# 3                       Cafeteria  Mexican Restaurant      974 College St
# 8   De La Salle College Cafeteria   College Cafeteria  131 Farnham Avenue
# 21                     Marketeria          Restaurant         30 Bond St.
# 23                        The Hub   College Cafeteria    350 Victoria St.
# 24                       One Hour  Chinese Restaurant    435 Spadina Ave.
# 26                  Innis College      Student Center        2 Sussex Ave
#
#           lat        lng postalCode state
# 1   43.655454 -79.399163    M5T 2G5    ON
# 3   43.653419 -79.427678    M6H 1A5    ON
# 8   43.683003 -79.397815    M4V 1H7    ON
# 21  43.653585 -79.378843    M5B 1W8    ON
# 23  43.658585 -79.380622    M5B 2K3    ON
# 24  43.657399 -79.399649    M5T 2T6    ON
# 26  43.665556 -79.399298    M5S 1J5    ON

# %% [markdown]
# <h2>Search For Shopping Store</h2>

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=4GJ5JOAPUZ03O2EQVND3C2TBFEYWEPVFNV1XH5SOGG3NMI2P&client_secret=SO4QNTWUJJEX50LHAKB0R34VE2GG1QRKJ3HFBTUXQO1UGU4X&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                535
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1                                                NaN     43.654265
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380567  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1570568914
# 1             ON                     CF Toronto Eaton Centre  v-1570568914
# 2             ON                TD Centre Shopping Concourse  v-1570568914
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1570568914
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1570568914

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       535
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1                                                NaN  43.654265 -79.380567
# 2  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.654265 -79.380567    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654265
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380567    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %% [markdown]
# <h2>Generate maps to visualize venues and how they cluster together</h2>

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                              name          categories                address  \
# 0   Sheraton Centre Toronto Hotel               Hotel  123 Queen Street West
# 1                  Grand Ballroom         Event Space        123 Queen St. W
# 2               Stay Cafeteria 慢走    Asian Restaurant        388 Spadina Ave
# 3                       Cafeteria  Mexican Restaurant         974 College St
# 4   De La Salle College Cafeteria   College Cafeteria     131 Farnham Avenue
# 5                      Marketeria          Restaurant            30 Bond St.
# 6                         The Hub   College Cafeteria       350 Victoria St.
# 7                        One Hour  Chinese Restaurant       435 Spadina Ave.
# 8                   Innis College      Student Center           2 Sussex Ave
# 9    Dragon City Shopping Mall 龍城       Shopping Mall        280 Spadina Ave
# 10        CF Toronto Eaton Centre       Shopping Mall           220 Yonge St
# 11   TD Centre Shopping Concourse       Shopping Mall     66 Wellington St W
#
#           lat        lng postalCode state
# 0   43.651144 -79.384329    M5H 2M9    ON
# 1   43.651217 -79.383771    M5H 2M9    ON
# 2   43.655454 -79.399163    M5T 2G5    ON
# 3   43.653419 -79.427678    M6H 1A5    ON
# 4   43.683003 -79.397815    M4V 1H7    ON
# 5   43.653585 -79.378843    M5B 1W8    ON
# 6   43.658585 -79.380622    M5B 2K3    ON
# 7   43.657399 -79.399649    M5T 2T6    ON
# 8   43.665556 -79.399298    M5S 1J5    ON
# 9   43.652774 -79.398222    M5T 3A5    ON
# 10  43.654265 -79.380567    M5B 2H1    ON
# 11  43.647184 -79.380932    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                           Trinity Bellwoods Park                     Park
# 1                                     Queen's Park                     Park
# 2                             Bellevue Square Park                     Park
# 3                              Riverdale Park East                     Park
# 4                              Riverdale Park West                     Park
# 5                                        High Park                     Park
# 6                               Canoe Landing Park                     Park
# 7                                  Coronation Park                     Park
# 8                                Osgoode Hall Park                     Park
# 9                              Dufferin Grove Park                     Park
# 10                 Hemispheres Restaurant & Bistro      American Restaurant
# 11                          Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 12                          Azure Restaurant & Bar               Restaurant
# 13                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 14                                  360 Restaurant                 Wine Bar
# 15                  The Hot House Restaurant & Bar      American Restaurant
# 16                  Goldstone Noodle Restaurant 金石             Noodle House
# 17                           Victoria's Restaurant               Restaurant
# 18                   Green Tea Restaurant Downtown       Chinese Restaurant
# 19                         Victor Restaurant & Bar                      Bar
# 20                    Aroma Fine Indian Restaurant        Indian Restaurant
# 21         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 22                        Ka Chi Korean Restaurant        Korean Restaurant
# 23             Richtree Natural Market Restaurants               Restaurant
# 24                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 25  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 26                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 27                     Woodlot Restaurant & Bakery  New American Restaurant
# 28               El Rancho Restaurant & Night Club                Nightclub
# 29                         The Lakeview Restaurant                    Diner
# 30                  Insomnia Restaurant and Lounge               Restaurant
# 31               Kensington Cornerstone Restaurant           Breakfast Spot
# 32                               Studio Restaurant           Breakfast Spot
# 33                            Montecito Restaurant               Restaurant
# 34                      Wah Too Seafood Restaurant       Chinese Restaurant
# 35                               SCHOOL Restaurant           Breakfast Spot
# 36                               Stay Cafeteria 慢走         Asian Restaurant
# 37                                       Cafeteria       Mexican Restaurant
# 38                   De La Salle College Cafeteria        College Cafeteria
# 39                                      Marketeria               Restaurant
# 40                                         The Hub        College Cafeteria
# 41                                        One Hour       Chinese Restaurant
# 42                                   Innis College           Student Center
#
#                             address        lat        lng postalCode state
# 0                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 1                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 2      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 3                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 4                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 5                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 6                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 7            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 8                    130 Queen St W  43.651105 -79.386269    M5H 2N5    ON
# 9                   875 Dufferin St  43.656052 -79.431915        M6H    ON
# 10              110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 11                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 12                    225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 13                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 14                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 15                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 16                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 17              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 18  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 19                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 20                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 21                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 22                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 23                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 24                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 25            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 26                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 27              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 28                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 29                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 30                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 31               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 32                   389 Church St.  43.661500 -79.379319        M5B    ON
# 33                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 34                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 35                   70 Fraser Ave.  43.637775 -79.424297    M6K 3C5    ON
# 36                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 37                   974 College St  43.653419 -79.427678    M6H 1A5    ON
# 38               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 39                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 40                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 41                 435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 42                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
